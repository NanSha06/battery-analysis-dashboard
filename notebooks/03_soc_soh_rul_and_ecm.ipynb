# %% [markdown]
# # SOC, SOH, RUL, and 2RC ECM
#
# This notebook assembles the digital shadow, estimates state variables, and fits a 2RC ECM for voltage reconstruction.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve().parent
if str(ROOT) not in sys.path:
    sys.path.append(str(ROOT))

from src.data_loader import load_shadow_tables
from src.ecm import attach_ecm_state, voltage_error_metrics
from src.state_estimators import build_shadow_state

# %%
cycle_table, sample_table = load_shadow_tables(ROOT / 'mat_files')
cycle_state, sample_state, soh_model = build_shadow_state(cycle_table, sample_table)
sample_shadow, ecm_params, ocv_curve = attach_ecm_state(sample_state)
metrics = voltage_error_metrics(sample_shadow)
cycle_state.head(), sample_shadow.head(), ecm_params, metrics
