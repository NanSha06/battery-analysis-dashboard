# %% [markdown]
# # Feature engineering and targets
#
# This notebook derives cycle-level features and health targets from the flattened battery tables.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve().parent
if str(ROOT) not in sys.path:
    sys.path.append(str(ROOT))

from src.data_loader import load_shadow_tables
from src.features import add_cycle_features, add_sample_features, summarize_discharge_cycles

# %%
cycle_table, sample_table = load_shadow_tables(ROOT / 'mat_files')
cycle_features = add_cycle_features(cycle_table)
sample_features = add_sample_features(sample_table)
discharge_summary = summarize_discharge_cycles(sample_features)
cycle_features.head(), discharge_summary.head()
