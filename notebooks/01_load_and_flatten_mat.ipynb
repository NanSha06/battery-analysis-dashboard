# %% [markdown]
# # Load and flatten MAT battery files
#
# This notebook loads the NASA Li-ion battery `.mat` files from `../mat_files` and produces normalized cycle-level and sample-level tables.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve().parent
if str(ROOT) not in sys.path:
    sys.path.append(str(ROOT))

from src.data_loader import load_shadow_tables

# %%
MAT_DIR = ROOT / 'mat_files'
cycle_table, sample_table = load_shadow_tables(MAT_DIR)
cycle_table.head(), sample_table.head()
